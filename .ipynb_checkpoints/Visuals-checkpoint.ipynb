# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./test.csv")
# Out:
# C:\Users\Akshay\AppData\Local\Temp\ipykernel_5524\3490918343.py:1: DtypeWarning: Columns (33,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./test.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  safetyreportversion  safetyreportid primarysourcecountry  \
# 0           0                   12        20967838                   US
# 1           1                    2        21013578                   US
# 2           2                    5        21054793                   US
# 3           3                    2        21131542                   CO
# 4           4                   10        21192965                   CA
#
#   occurcountry  transmissiondateformat  transmissiondate  reporttype  serious  \
# 0           US                     102          20240410         1.0        2
# 1           US                     102          20240410         2.0        2
# 2           US                     102          20240410         1.0        1
# 3           CO                     102          20240410         2.0        1
# 4          NaN                     102          20240410         3.0        1
#
#    seriousnessdeath  ...  drugenddate  drugtreatmentduration  \
# 0               2.0  ...          NaN                    NaN
# 1               2.0  ...          NaN                    NaN
# 2               2.0  ...          NaN                    NaN
# 3               2.0  ...   20231221.0                  470.0
# 4               2.0  ...          NaN                    NaN
#
#    drugtreatmentdurationunit  drugrecurreadministration  drugadditional  \
# 0                        NaN                        NaN             NaN
# 1                        NaN                        NaN             NaN
# 2                        NaN                        NaN             NaN
# 3                      804.0                        3.0             3.0
# 4                        NaN                        NaN             3.0
#
#    authoritynumb  drugcumulativedosagenumb  drugcumulativedosageunit  \
# 0            NaN                       NaN                       NaN
# 1            NaN                       NaN                       NaN
# 2            NaN                       NaN                       NaN
# 3            NaN                       NaN                       NaN
# 4            NaN                       NaN                       NaN
#
#    literaturereference  drugrecurrence
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# ## EDA

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'safetyreportversion', 'safetyreportid',
#        'primarysourcecountry', 'occurcountry', 'transmissiondateformat',
#        'transmissiondate', 'reporttype', 'serious', 'seriousnessdeath',
#        'seriousnesslifethreatening', 'seriousnesshospitalization',
#        'seriousnessdisabling', 'seriousnesscongenitalanomali',
#        'seriousnessother', 'receivedateformat', 'receivedate',
#        'receiptdateformat', 'receiptdate', 'fulfillexpeditecriteria',
#        'companynumb', 'reportercountry', 'qualification', 'sendertype',
#        'senderorganization', 'receivertype', 'receiverorganization',
#        'reactionmeddraversionpt', 'reactionmeddrapt', 'reactionoutcome',
#        'drugcharacterization', 'medicinalproduct', 'drugbatchnumb',
#        'drugauthorizationnumb', 'drugstructuredosagenumb',
#        'drugstructuredosageunit', 'drugseparatedosagenumb',
#        'drugintervaldosageunitnumb', 'drugintervaldosagedefinition',
#        'drugdosagetext', 'drugdosageform', 'drugadministrationroute',
#        'drugindication', 'drugstartdateformat', 'drugstartdate', 'actiondrug',
#        'activesubstance', 'openfda', 'duplicate', 'reportduplicate',
#        'drugenddateformat', 'drugenddate', 'drugtreatmentduration',
#        'drugtreatmentdurationunit', 'drugrecurreadministration',
#        'drugadditional', 'authoritynumb', 'drugcumulativedosagenumb',
#        'drugcumulativedosageunit', 'literaturereference', 'drugrecurrence'],
#       dtype='object')

# %%
for idx,c in enumerate(list(df.columns)[1:]):
    print("########{}##########".format(idx))
    print(df[c].head())
    print("####################")
# Out:
# ########0##########
# 0    12
# 1     2
# 2     5
# 3     2
# 4    10
# Name: safetyreportversion, dtype: int64
# ####################
# ########1##########
# 0    20967838
# 1    21013578
# 2    21054793
# 3    21131542
# 4    21192965
# Name: safetyreportid, dtype: int64
# ####################
# ########2##########
# 0    US
# 1    US
# 2    US
# 3    CO
# 4    CA
# Name: primarysourcecountry, dtype: object
# ####################
# ########3##########
# 0     US
# 1     US
# 2     US
# 3     CO
# 4    NaN
# Name: occurcountry, dtype: object
# ####################
# ########4##########
# 0    102
# 1    102
# 2    102
# 3    102
# 4    102
# Name: transmissiondateformat, dtype: int64
# ####################
# ########5##########
# 0    20240410
# 1    20240410
# 2    20240410
# 3    20240410
# 4    20240410
# Name: transmissiondate, dtype: int64
# ####################
# ########6##########
# 0    1.0
# 1    2.0
# 2    1.0
# 3    2.0
# 4    3.0
# Name: reporttype, dtype: float64
# ####################
# ########7##########
# 0    2
# 1    2
# 2    1
# 3    1
# 4    1
# Name: serious, dtype: int64
# ####################
# ########8##########
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: seriousnessdeath, dtype: float64
# ####################
# ########9##########
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: seriousnesslifethreatening, dtype: float64
# ####################
# ########10##########
# 0    2.0
# 1    2.0
# 2    2.0
# 3    1.0
# 4    2.0
# Name: seriousnesshospitalization, dtype: float64
# ####################
# ########11##########
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: seriousnessdisabling, dtype: float64
# ####################
# ########12##########
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: seriousnesscongenitalanomali, dtype: float64
# ####################
# ########13##########
# 0    2.0
# 1    2.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: seriousnessother, dtype: float64
# ####################
# ########14##########
# 0    102.0
# 1    102.0
# 2    102.0
# 3    102.0
# 4    102.0
# Name: receivedateformat, dtype: float64
# ####################
# ########15##########
# 0    20220616
# 1    20220627
# 2    20220707
# 3    20220726
# 4    20220810
# Name: receivedate, dtype: int64
# ####################
# ########16##########
# 0    102
# 1    102
# 2    102
# 3    102
# 4    102
# Name: receiptdateformat, dtype: int64
# ####################
# ########17##########
# 0    20240126
# 1    20240111
# 2    20240118
# 3    20240311
# 4    20240102
# Name: receiptdate, dtype: int64
# ####################
# ########18##########
# 0    2
# 1    2
# 2    1
# 3    1
# 4    1
# Name: fulfillexpeditecriteria, dtype: int64
# ####################
# ########19##########
# 0      US-PFIZER INC-202200839769
# 1         US-SA-SAC20220621002010
# 2    US-PFIZER INC-PV202200016399
# 3             CO-UCBSA-2022041024
# 4                CA-ROCHE-2893929
# Name: companynumb, dtype: object
# ####################
# ########20##########
# 0    US
# 1    US
# 2    US
# 3    CO
# 4    CA
# Name: reportercountry, dtype: object
# ####################
# ########21##########
# 0    5.0
# 1    1.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: qualification, dtype: float64
# ####################
# ########22##########
# 0    2.0
# 1    2.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: sendertype, dtype: float64
# ####################
# ########23##########
# 0    FDA-Public Use
# 1    FDA-Public Use
# 2    FDA-Public Use
# 3    FDA-Public Use
# 4    FDA-Public Use
# Name: senderorganization, dtype: object
# ####################
# ########24##########
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: receivertype, dtype: int64
# ####################
# ########25##########
# 0    FDA
# 1    FDA
# 2    FDA
# 3    FDA
# 4    FDA
# Name: receiverorganization, dtype: object
# ####################
# ########26##########
# 0    26.1
# 1    26.1
# 2    26.1
# 3    26.1
# 4    26.1
# Name: reactionmeddraversionpt, dtype: float64
# ####################
# ########27##########
# 0                                  Fatigue
# 1    General physical health deterioration
# 2                                   Stress
# 3                            Off label use
# 4          Frustration tolerance decreased
# Name: reactionmeddrapt, dtype: object
# ####################
# ########28##########
# 0    3.0
# 1    6.0
# 2    6.0
# 3    6.0
# 4    6.0
# Name: reactionoutcome, dtype: float64
# ####################
# ########29##########
# 0    1
# 1    1
# 2    2
# 3    2
# 4    1
# Name: drugcharacterization, dtype: int64
# ####################
# ########30##########
# 0                                    VYNDAMAX
# 1                                   DUPILUMAB
# 2    SYSTANE (HYPROMELLOSE 2910 (4000 MPA.S))
# 3                                 INSULIN NOS
# 4                                     OCREVUS
# Name: medicinalproduct, dtype: object
# ####################
# ########31##########
# 0             4788385A
# 1                  NaN
# 2              8146570
# 3                  NaN
# 4    ASKED BUT UNKNOWN
# Name: drugbatchnumb, dtype: object
# ####################
# ########32##########
# 0    212161.0
# 1    761055.0
# 2     22030.0
# 3         NaN
# 4    761053.0
# Name: drugauthorizationnumb, dtype: object
# ####################
# ########33##########
# 0     61.0
# 1    300.0
# 2      0.1
# 3    400.0
# 4    300.0
# Name: drugstructuredosagenumb, dtype: float64
# ####################
# ########34##########
# 0     3.0
# 1     3.0
# 2    30.0
# 3     3.0
# 4     3.0
# Name: drugstructuredosageunit, dtype: float64
# ####################
# ########35##########
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: drugseparatedosagenumb, dtype: float64
# ####################
# ########36##########
# 0    1.0
# 1    2.0
# 2    1.0
# 3    4.0
# 4    2.0
# Name: drugintervaldosageunitnumb, dtype: float64
# ####################
# ########37##########
# 0    804.0
# 1    803.0
# 2    804.0
# 3    803.0
# 4    803.0
# Name: drugintervaldosagedefinition, dtype: float64
# ####################
# ########38##########
# 0                                        61 MG, 1X/DAY
# 1                                          300 MG, QOW
# 2                                     2-3 TIME PER DAY
# 3                                                  UNK
# 4    300 MG AT DAY 0 AND 14, THEN 600 MG EVERY 6 MONTH
# Name: drugdosagetext, dtype: object
# ####################
# ########39##########
# 0             Capsule, soft
# 1    Solution for injection
# 2       Ear drops, solution
# 3                       NaN
# 4        Infusion, Solution
# Name: drugdosageform, dtype: object
# ####################
# ########40##########
# 0    48.0
# 1    58.0
# 2    61.0
# 3    58.0
# 4    42.0
# Name: drugadministrationroute, dtype: float64
# ####################
# ########41##########
# 0                       Cardiac amyloidosis
# 1                         Dermatitis atopic
# 2                                   Dry eye
# 3                         Diabetes mellitus
# 4    Relapsing-remitting multiple sclerosis
# Name: drugindication, dtype: object
# ####################
# ########42##########
# 0    102.0
# 1    610.0
# 2    610.0
# 3    102.0
# 4    102.0
# Name: drugstartdateformat, dtype: float64
# ####################
# ########43##########
# 0    20220528.0
# 1      202205.0
# 2      202205.0
# 3    20220908.0
# 4    20200115.0
# Name: drugstartdate, dtype: float64
# ####################
# ########44##########
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: actiondrug, dtype: float64
# ####################
# ########45##########
# 0                 {'activesubstancename': 'TAFAMIDIS'}
# 1                 {'activesubstancename': 'DUPILUMAB'}
# 2    {'activesubstancename': 'HYPROMELLOSE 2910 (40...
# 3               {'activesubstancename': 'INSULIN NOS'}
# 4               {'activesubstancename': 'OCRELIZUMAB'}
# Name: activesubstance, dtype: object
# ####################
# ########46##########
# 0    {'application_number': ['NDA212161'], 'brand_n...
# 1    {'application_number': ['BLA761055'], 'brand_n...
# 2    {'application_number': ['ANDA206519', 'ANDA201...
# 3    {'application_number': ['ANDA215959'], 'brand_...
# 4    {'application_number': ['BLA761053'], 'brand_n...
# Name: openfda, dtype: object
# ####################
# ########47##########
# 0    NaN
# 1    1.0
# 2    NaN
# 3    1.0
# 4    NaN
# Name: duplicate, dtype: float64
# ####################
# ########48##########
# 0                                                  NaN
# 1    [{'duplicatesource': 'SA', 'duplicatenumb': 'U...
# 2                                                  NaN
# 3    [{'duplicatesource': '22', 'duplicatenumb': 'C...
# 4                                                  NaN
# Name: reportduplicate, dtype: object
# ####################
# ########49##########
# 0      NaN
# 1      NaN
# 2      NaN
# 3    102.0
# 4      NaN
# Name: drugenddateformat, dtype: float64
# ####################
# ########50##########
# 0           NaN
# 1           NaN
# 2           NaN
# 3    20231221.0
# 4           NaN
# Name: drugenddate, dtype: float64
# ####################
# ########51##########
# 0      NaN
# 1      NaN
# 2      NaN
# 3    470.0
# 4      NaN
# Name: drugtreatmentduration, dtype: float64
# ####################
# ########52##########
# 0      NaN
# 1      NaN
# 2      NaN
# 3    804.0
# 4      NaN
# Name: drugtreatmentdurationunit, dtype: float64
# ####################
# ########53##########
# 0    NaN
# 1    NaN
# 2    NaN
# 3    3.0
# 4    NaN
# Name: drugrecurreadministration, dtype: float64
# ####################
# ########54##########
# 0    NaN
# 1    NaN
# 2    NaN
# 3    3.0
# 4    3.0
# Name: drugadditional, dtype: float64
# ####################
# ########55##########
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: authoritynumb, dtype: object
# ####################
# ########56##########
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: drugcumulativedosagenumb, dtype: float64
# ####################
# ########57##########
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: drugcumulativedosageunit, dtype: float64
# ####################
# ########58##########
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: literaturereference, dtype: object
# ####################
# ########59##########
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: drugrecurrence, dtype: object
# ####################

# %%
new_df = df[['safetyreportid','primarysourcecountry', 'occurcountry', 'transmissiondateformat',
       'transmissiondate', 'reporttype', 'serious', 'seriousnessdeath','seriousnesslifethreatening',
        'seriousnesshospitalization','seriousnessdisabling', 'seriousnesscongenitalanomali',
       'seriousnessother', 'receivedateformat', 'receivedate','receiptdateformat', 'receiptdate',
        'companynumb','reactionmeddrapt','reactionoutcome','drugcharacterization',"medicinalproduct",
        "drugdosagetext","drugdosageform","drugindication",'drugstartdateformat', 'drugstartdate',
        'activesubstance','drugenddateformat', 'drugenddate','drugtreatmentduration']]

# %%
new_df.describe()
# Out:
#        safetyreportid  transmissiondateformat  transmissiondate    reporttype  \
# count    1.127336e+06               1127336.0      1.127336e+06  1.127009e+06
# mean     2.350275e+07                   102.0      2.024073e+07  1.237663e+00
# std      1.279751e+06                     0.0      2.490229e+02  4.826140e-01
# min      3.964992e+06                   102.0      2.024041e+07  1.000000e+00
# 25%      2.347097e+07                   102.0      2.024041e+07  1.000000e+00
# 50%      2.377567e+07                   102.0      2.024072e+07  1.000000e+00
# 75%      2.407317e+07                   102.0      2.024102e+07  1.000000e+00
# max      2.442453e+07                   102.0      2.024102e+07  3.000000e+00
#
#             serious  seriousnessdeath  seriousnesslifethreatening  \
# count  1.127336e+06      1.076552e+06                1.077384e+06
# mean   1.449907e+00      1.921801e+00                1.966618e+00
# std    4.974846e-01      2.684842e-01                1.796315e-01
# min    1.000000e+00      1.000000e+00                1.000000e+00
# 25%    1.000000e+00      2.000000e+00                2.000000e+00
# 50%    1.000000e+00      2.000000e+00                2.000000e+00
# 75%    2.000000e+00      2.000000e+00                2.000000e+00
# max    2.000000e+00      2.000000e+00                2.000000e+00
#
#        seriousnesshospitalization  seriousnessdisabling  \
# count                1.087770e+06          1.072620e+06
# mean                 1.784328e+00          1.983841e+00
# std                  4.112876e-01          1.260888e-01
# min                  1.000000e+00          1.000000e+00
# 25%                  2.000000e+00          2.000000e+00
# 50%                  2.000000e+00          2.000000e+00
# 75%                  2.000000e+00          2.000000e+00
# max                  2.000000e+00          2.000000e+00
#
#        seriousnesscongenitalanomali  ...   receivedate  receiptdateformat  \
# count                  1.071932e+06  ...  1.127336e+06          1127336.0
# mean                   1.997357e+00  ...  2.023772e+07              102.0
# std                    5.134111e-02  ...  8.860253e+03                0.0
# min                    1.000000e+00  ...  2.003062e+07              102.0
# 25%                    2.000000e+00  ...  2.024020e+07              102.0
# 50%                    2.000000e+00  ...  2.024042e+07              102.0
# 75%                    2.000000e+00  ...  2.024071e+07              102.0
# max                    2.000000e+00  ...  2.024093e+07              102.0
#
#         receiptdate  reactionoutcome  drugcharacterization  \
# count  1.127336e+06     1.081296e+06          1.127336e+06
# mean   2.024053e+07     4.786473e+00          1.275786e+00
# std    2.588428e+02     1.884026e+00          4.537196e-01
# min    2.024010e+07     1.000000e+00          1.000000e+00
# 25%    2.024031e+07     3.000000e+00          1.000000e+00
# 50%    2.024052e+07     6.000000e+00          1.000000e+00
# 75%    2.024073e+07     6.000000e+00          2.000000e+00
# max    2.024093e+07     6.000000e+00          3.000000e+00
#
#        drugstartdateformat  drugstartdate  drugenddateformat   drugenddate  \
# count        545572.000000   5.455720e+05      236590.000000  2.365900e+05
# mean            271.378861   1.349722e+07         225.424912  1.532271e+07
# std             238.675081   9.476900e+06         217.135916  8.632396e+06
# min             102.000000   1.895000e+03         102.000000  1.900000e+03
# 25%             102.000000   2.023110e+05         102.000000  2.012032e+07
# 50%             102.000000   2.022070e+07         102.000000  2.023100e+07
# 75%             602.000000   2.023123e+07         102.000000  2.024032e+07
# max             610.000000   2.209100e+07         610.000000  2.026042e+07
#
#        drugtreatmentduration
# count          169084.000000
# mean              157.358957
# std               963.849459
# min                 0.000000
# 25%                 1.000000
# 50%                 7.000000
# 75%                59.000000
# max             99999.000000
#
# [8 rows x 22 columns]

# %%
sns.heatmap(new_df.isnull())
# Out:
# <Axes: >

# %%
df.drop(["drugadministrationroute","drugbatchnumb","literaturereference","drugrecurreadministration","authoritynumb"],inplace = True,axis = 1)

# %%
df.head()
# Out:
#    Unnamed: 0  safetyreportversion  safetyreportid primarysourcecountry  \
# 0           0                    2        23646525                   IT
# 1           1                    1        23649399                   US
# 2           2                    1        23652290                   US
# 3           3                    1        23657918                   US
# 4           4                    1        23542494                   US
#
#   occurcountry  transmissiondateformat  transmissiondate  reporttype  serious  \
# 0           IT                     102          20240410         2.0        1
# 1           US                     102          20240410         1.0        2
# 2           US                     102          20240409         2.0        1
# 3           US                     102          20240409         1.0        2
# 4           US                     102          20240410         1.0        2
#
#    seriousnessdeath  ...  drugenddate  drugtreatmentduration  \
# 0               2.0  ...   20240308.0                    1.0
# 1               2.0  ...          NaN                    NaN
# 2               2.0  ...          NaN                    NaN
# 3               2.0  ...          NaN                    NaN
# 4               2.0  ...          NaN                    NaN
#
#    drugtreatmentdurationunit  actiondrug  drugadditional  \
# 0                      804.0         1.0             1.0
# 1                        NaN         5.0             3.0
# 2                        NaN         5.0             3.0
# 3                        NaN         5.0             3.0
# 4                        NaN         5.0             3.0
#
#                                activesubstance  \
# 0  {'activesubstancename': 'THIOCOLCHICOSIDE'}
# 1       {'activesubstancename': 'DULAGLUTIDE'}
# 2     {'activesubstancename': 'EMPAGLIFLOZIN'}
# 3       {'activesubstancename': 'TIRZEPATIDE'}
# 4       {'activesubstancename': 'DULAGLUTIDE'}
#
#                                              openfda  \
# 0  {'application_number': ['ANDA212506', 'ANDA209...
# 1  {'application_number': ['BLA125469'], 'brand_n...
# 2  {'application_number': ['NDA204629'], 'brand_n...
# 3  {'application_number': ['NDA215866'], 'brand_n...
# 4  {'application_number': ['BLA125469'], 'brand_n...
#
#    drugcumulativedosagenumb  drugcumulativedosageunit  \
# 0                       2.0                      32.0
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#                              drugdosageform
# 0                                       NaN
# 1  Solution for injection in pre-filled pen
# 2                        Film-coated tablet
# 3  Solution for injection in pre-filled pen
# 4  Solution for injection in pre-filled pen
#
# [5 rows x 55 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
new_df = df[["drugindication","reactionmeddrapt","medicinalproduct"]]

# %%
new_df.head()
# Out:
#                         drugindication       reactionmeddrapt  \
# 0  Product used for unknown indication  Drug hypersensitivity
# 1  Product used for unknown indication                Obesity
# 2  Product used for unknown indication               Overdose
# 3                    Diabetes mellitus                Illness
# 4  Product used for unknown indication     Metabolic disorder
#
#    medicinalproduct
# 0  THIOCOLCHICOSIDE
# 1         TRULICITY
# 2         JARDIANCE
# 3          MOUNJARO
# 4         TRULICITY

# %%
sns.heatmap(new_df.isnull())
# Out:
# <Axes: >

# %%
new_df.dropna(inplace = True)
# Out:
# C:\Users\Akshay\AppData\Local\Temp\ipykernel_3820\117842389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(inplace = True)

# %% [markdown]
# ### Most Common Drug Indication

# %%
gk = new_df.groupby('drugindication')

# %%
unique_drugindication = gk.first().index

# %%
count_reaction = {}
for drug in unique_drugindication:
    count_reaction[drug] = len(gk.get_group(drug))

# %%
res = dict(sorted(count_reaction.items(), key = lambda x: x[1], reverse = True)[1:11])

# %%
res
# Out:
# {'Rheumatoid arthritis': 2881,
#  'Plasma cell myeloma': 2085,
#  'Asthma': 2011,
#  'Dermatitis atopic': 1942,
#  'Type 2 diabetes mellitus': 1886,
#  'Crohn^s disease': 1786,
#  'Colitis ulcerative': 1502,
#  'Multiple sclerosis': 1325,
#  'Hypertension': 994,
#  'Psoriasis': 974}

# %%
plt.figure(figsize=(10, 6))
fig, ax = plt.subplots() 
# Creating plot
ax.bar(res.keys(),res.values())
 
# Rotating X-axis labels
ax.set_xticklabels(res.keys(), rotation = 90)
 
# Setting title
plt.title('Most Common Disease')
 
# Show plot
plt.show()
# Out:
# C:\Users\Akshay\AppData\Local\Temp\ipykernel_3820\3495198209.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(res.keys(), rotation = 90)

# %% [markdown]
# ### Most Common Medicinal Product

# %%
gk = new_df.groupby('medicinalproduct')
unique_reactionmeddrapt = gk.first().index
count_reaction = {}
for drug in unique_reactionmeddrapt:
    count_reaction[drug] = len(gk.get_group(drug))
res = dict(sorted(count_reaction.items(), key = lambda x: x[1], reverse = True)[:10])

# %%
plt.figure(figsize=(10, 6))
fig, ax = plt.subplots() 
# Creating plot
ax.bar(res.keys(),res.values())
 
# Rotating X-axis labels
ax.set_xticklabels(res.keys(), rotation = 90)
 
# Setting title
plt.title('Most Used Medicines')
 
# Show plot
plt.show()
# Out:
# C:\Users\Akshay\AppData\Local\Temp\ipykernel_3820\1305074406.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(res.keys(), rotation = 90)

# %% [markdown]
# ### Most Common Drugs Reaction

# %%
gk = new_df.groupby('reactionmeddrapt')
unique_reactionmeddrapt = gk.first().index
count_reaction = {}
for drug in unique_reactionmeddrapt:
    count_reaction[drug] = len(gk.get_group(drug))
res = dict(sorted(count_reaction.items(), key = lambda x: x[1], reverse = True)[8:18])

# %%
plt.figure(figsize=(10, 6))
fig, ax = plt.subplots() 
# Creating plot
ax.bar(res.keys(),res.values())
 
# Rotating X-axis labels
ax.set_xticklabels(res.keys(), rotation = 90)
 
# Setting title
plt.title('Most Common Side-Effects')
 
# Show plot
plt.show()
# Out:
# C:\Users\Akshay\AppData\Local\Temp\ipykernel_3820\2827971138.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(res.keys(), rotation = 90)
